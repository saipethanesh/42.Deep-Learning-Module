# %%
#!pip install pydot

# %%
#!pip install tensorflow

# %%
# Basic Libraries
import numpy as np
import pandas as pd

# Visualization libraries
import matplotlib.pyplot as plt
import pydot
import seaborn as sns

#Evaluation library
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# Deep Learning libraries
import tensorflow as tf
from tensorflow.keras import layers
import keras
from keras.models import Sequential
from keras.layers.core import Dense,Activation,Dropout
from keras.datasets import mnist
from keras.utils.np_utils import to_categorical
from keras.wrappers.scikit_learn import KerasClassifier

# %%
fashion_train=pd.read_csv("fashion-mnist_train.csv")
fashion_test=pd.read_csv("fashion-mnist_test.csv")

# %%
fashion_train.shape
# Out:
# (60000, 785)

# %%
X_train_fashion = fashion_train.drop('label',axis = 1)
y_train_fashion = fashion_train['label']
X_test_fashion = fashion_test.drop('label',axis = 1)
y_test_fashion = fashion_test['label']

# %%
#Reshaping the dataset
x_train_reshape = X_train_fashion.values.reshape(-1,28,28)
x_test_reshape = X_test_fashion.values.reshape(-1,28,28)

#Names of clothing accessories in order 
col_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

#Visualizing the images
plt.figure(figsize=(10,10))
for i in range(15):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train_reshape[i], cmap='gray')
    plt.xlabel(col_names[y_train_fashion[i]])
plt.show()

# %%
y_train_fashion = to_categorical(y_train_fashion, num_classes=10)

y_test_fashion = to_categorical(y_test_fashion, num_classes=10)

# %%
#Creating base neural network
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(784,)),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(24, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(24, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(10,activation='softmax'),
])

#Compiling the model
model.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics = ['accuracy'])

#Fitting the model
history=model.fit(X_train_fashion, y_train_fashion, batch_size=100, epochs=30,validation_data=(X_test_fashion, y_test_fashion))
# Out:
# Epoch 1/30
# 600/600 [==============================] - 15s 8ms/step - loss: 1.1149 - accuracy: 0.6137 - val_loss: 0.5673 - val_accuracy: 0.7868
# Epoch 2/30
# 600/600 [==============================] - 4s 7ms/step - loss: 0.7447 - accuracy: 0.7437 - val_loss: 0.5173 - val_accuracy: 0.8316
# Epoch 3/30
# 600/600 [==============================] - 7s 12ms/step - loss: 0.6802 - accuracy: 0.7703 - val_loss: 0.4977 - val_accuracy: 0.8405
# Epoch 4/30
# 600/600 [==============================] - 8s 13ms/step - loss: 0.6489 - accuracy: 0.7798 - val_loss: 0.5133 - val_accuracy: 0.8422
# Epoch 5/30
# 600/600 [==============================] - 5s 9ms/step - loss: 0.6321 - accuracy: 0.7879 - val_loss: 0.4787 - val_accuracy: 0.8564
# Epoch 6/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.6093 - accuracy: 0.7943 - val_loss: 0.4794 - val_accuracy: 0.8519
# Epoch 7/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5864 - accuracy: 0.8028 - val_loss: 0.4541 - val_accuracy: 0.8503
# Epoch 8/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5809 - accuracy: 0.8052 - val_loss: 0.4877 - val_accuracy: 0.8561
# Epoch 9/30
# 600/600 [==============================] - 5s 9ms/step - loss: 0.5684 - accuracy: 0.8098 - val_loss: 0.4536 - val_accuracy: 0.8631
# Epoch 10/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5620 - accuracy: 0.8135 - val_loss: 0.4773 - val_accuracy: 0.8576
# Epoch 11/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5586 - accuracy: 0.8154 - val_loss: 0.4768 - val_accuracy: 0.8607
# Epoch 12/30
# 600/600 [==============================] - 5s 9ms/step - loss: 0.5521 - accuracy: 0.8179 - val_loss: 0.4486 - val_accuracy: 0.8625
# Epoch 13/30
# 600/600 [==============================] - 5s 9ms/step - loss: 0.5449 - accuracy: 0.8182 - val_loss: 0.4546 - val_accuracy: 0.8667
# Epoch 14/30
# 600/600 [==============================] - 6s 9ms/step - loss: 0.5449 - accuracy: 0.8173 - val_loss: 0.4549 - val_accuracy: 0.8542
# Epoch 15/30
# 600/600 [==============================] - 5s 9ms/step - loss: 0.5368 - accuracy: 0.8214 - val_loss: 0.4566 - val_accuracy: 0.8587
# Epoch 16/30
# 600/600 [==============================] - 6s 10ms/step - loss: 0.5339 - accuracy: 0.8214 - val_loss: 0.4384 - val_accuracy: 0.8670
# Epoch 17/30
# 600/600 [==============================] - 6s 10ms/step - loss: 0.5286 - accuracy: 0.8238 - val_loss: 0.4509 - val_accuracy: 0.8612
# Epoch 18/30
# 600/600 [==============================] - 6s 10ms/step - loss: 0.5299 - accuracy: 0.8235 - val_loss: 0.4711 - val_accuracy: 0.8539
# Epoch 19/30
# 600/600 [==============================] - 5s 9ms/step - loss: 0.5257 - accuracy: 0.8251 - val_loss: 0.4185 - val_accuracy: 0.8698
# Epoch 20/30
# 600/600 [==============================] - 6s 9ms/step - loss: 0.5261 - accuracy: 0.8243 - val_loss: 0.4265 - val_accuracy: 0.8643
# Epoch 21/30
# 600/600 [==============================] - 5s 9ms/step - loss: 0.5214 - accuracy: 0.8263 - val_loss: 0.4052 - val_accuracy: 0.8710
# Epoch 22/30
# 600/600 [==============================] - 5s 9ms/step - loss: 0.5150 - accuracy: 0.8286 - val_loss: 0.4135 - val_accuracy: 0.8670
# Epoch 23/30
# 600/600 [==============================] - 6s 10ms/step - loss: 0.5136 - accuracy: 0.8293 - val_loss: 0.4215 - val_accuracy: 0.8664
# Epoch 24/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5156 - accuracy: 0.8281 - val_loss: 0.4197 - val_accuracy: 0.8637
# Epoch 25/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5113 - accuracy: 0.8306 - val_loss: 0.4037 - val_accuracy: 0.8726
# Epoch 26/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5053 - accuracy: 0.8313 - val_loss: 0.4299 - val_accuracy: 0.8661
# Epoch 27/30
# 600/600 [==============================] - 5s 9ms/step - loss: 0.5087 - accuracy: 0.8316 - val_loss: 0.4172 - val_accuracy: 0.8649
# Epoch 28/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5103 - accuracy: 0.8314 - val_loss: 0.4144 - val_accuracy: 0.8730
# Epoch 29/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5000 - accuracy: 0.8328 - val_loss: 0.4131 - val_accuracy: 0.8688
# Epoch 30/30
# 600/600 [==============================] - 5s 9ms/step - loss: 0.4997 - accuracy: 0.8351 - val_loss: 0.4025 - val_accuracy: 0.8761

# %%
test_loss_fashion, test_acc_fashion = model.evaluate(X_test_fashion, y_test_fashion)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4025 - accuracy: 0.8761

# %%
print('Fashion MNIST Test accuracy:', round(test_acc_fashion,4))
# Out:
# Fashion MNIST Test accuracy: 0.8761

# %%
#Predicting the labels-Fashion
y_predict_fash = model.predict(X_test_fashion)
y_predict_fash=np.argmax(y_predict_fash, axis=1)
y_test_fash_eval=np.argmax(y_test_fashion, axis=1)
# Out:
# 313/313 [==============================] - 2s 3ms/step

# %%
con_mat=confusion_matrix(y_test_fash_eval,y_predict_fash)
plt.style.use('seaborn-deep')
plt.figure(figsize=(10,10))
sns.heatmap(con_mat,annot=True,annot_kws={'size': 15},linewidths=0.5,fmt="d",cmap="gray")
plt.title('True or False predicted Fashion MNIST\n',fontweight='bold',fontsize=15)
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test_fash_eval,y_predict_fash))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81      1000
#            1       0.98      0.98      0.98      1000
#            2       0.77      0.81      0.79      1000
#            3       0.90      0.88      0.89      1000
#            4       0.76      0.87      0.81      1000
#            5       0.97      0.94      0.95      1000
#            6       0.73      0.61      0.67      1000
#            7       0.92      0.95      0.93      1000
#            8       0.97      0.97      0.97      1000
#            9       0.95      0.95      0.95      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
#tf.expand_dims(X_test_digit[0])
y_predict = model.predict(X_test_fashion.loc[[0],:].values)
y_predict=np.argmax(y_predict, axis=1) # Here we get the index of maximum value in the encoded vector
y_test_digit_eval=np.argmax(y_test_fashion, axis=1)
# Out:
# 1/1 [==============================] - 0s 51ms/step

# %%
#Names of clothing accessories in order 
col_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

#Visualizing the images
plt.figure(figsize=(10,10))

plt.imshow(x_train_reshape[0], cmap='gray')
plt.xlabel("Actual:{},Pred:{}".format(col_names[np.argmax(y_test_fashion[0])],col_names[y_predict[0]]))
plt.show()
